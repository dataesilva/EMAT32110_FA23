# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
ces = pd.read_csv('cces_example_data.csv')

# %%
ces.head()
# Out:
#    pew_religimp  pew_churatd  sex  educ  nonwhite  age  faminc_new  pid3  \
# 0             2            6    2     2         1   56           6     1
# 1             2            4    2     5         1   53          13     1
# 2             1            2    1     2         1   69          10     2
# 3             2            3    1     6         1   76          97     1
# 4             4            5    2     6         1   83           4     1
#
#    ideo5  QueerPhobia  ...  InterGBiasParty  InterGBiasCand  InterGBiasSup  \
# 0      1     1.000000  ...              -99             -99            -96
# 1      2     3.000000  ...             -100            -100           -100
# 2      5     4.333333  ...               99              99             96
# 3      3     1.000000  ...              -86             -91            -89
# 4      2     1.000000  ...              -80             -88            -87
#
# ...

# %%
fig1, ax1 = plt.subplots(8, 3, figsize = (15, 10))
ax1[5, 1].set_title('hi')



plt.show()

# %%
ces.columns
# Out:
# Index(['pew_religimp', 'pew_churatd', 'sex', 'educ', 'nonwhite', 'age',
#        'faminc_new', 'pid3', 'ideo5', 'QueerPhobia', 'ImmiPhobia',
#        'InterGBiasParty', 'InterGBiasCand', 'InterGBiasSup', 'LibMediaUse',
#        'ConMediaUse', 'Real_Threat', 'Symb_Threat', 'Evaluation', 'teamweight',
#        'caseid'],
#       dtype='object')

# %%
fig2, ax2 = plt.subplots(1, 2)
ax2[0].hist(ces['InterGBiasCand'])
ax2[1].boxplot(ces['InterGBiasCand'])

plt.show()

# %%
fig3, ax3 = plt.subplots()
ax3.boxplot(ces['InterGBiasCand'], positions = [1])
ax3.boxplot(ces['InterGBiasSup'], positions = [2])
ax3.boxplot(ces['InterGBiasParty'], positions = [3])

plt.show()

# %%
ces.shape
# Out:
# (659, 21)

# %%
polid = ces.groupby('pid3').count()['caseid']

# %%
polid.index
# Out:
# Index([1, 2, 3], dtype='int64', name='pid3')

# %%
polid.values
# Out:
# array([251, 172, 236], dtype=int64)

# %%
fig4, ax4 = plt.subplots()
ax4.pie(polid.values, explode = [.25, 0, 0], labels = polid.index)

plt.show()

# %%
polid.sort_values()
# Out:
# pid3
# 2    172
# 3    236
# 1    251
# Name: caseid, dtype: int64

# %%
fig5, ax5 = plt.subplots()
ax5.bar(x = [1, 2, 3], height = polid.sort_values(ascending = False).values)

plt.show()
