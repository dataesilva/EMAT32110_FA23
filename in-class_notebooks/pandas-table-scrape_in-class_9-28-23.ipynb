# %%
import pandas as pd
import requests

# %%
wwc_wiki = pd.read_html('https://en.wikipedia.org/wiki/FIFA_World_Cup')

# %%
type(wwc_wiki)
# Out:
# list

# %%
wwc_wiki[3]
# Out:
#        Year                        Hosts Venues/Cities Totalattendance †  \
#        Year                        Hosts Venues/Cities Totalattendance †
# 0      1930                      Uruguay           3/1          590549.0
# 1      1934                        Italy           8/8          363000.0
# 2      1938                       France          10/9          375700.0
# 3      1950                       Brazil           6/6         1045246.0
# 4      1954                  Switzerland           6/6          768607.0
# 5      1958                       Sweden         12/12          819810.0
# 6      1962                        Chile           4/4          893172.0
# 7      1966                      England           8/7         1563135.0
# 8      1970                       Mexico           5/5         1603975.0
# 9      1974                 West Germany           9/9         1865753.0
# 10     1978                    Argentina           6/5         1545791.0
# ...
