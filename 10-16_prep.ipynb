# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
ces = pd.read_csv('in-class_notebooks/cces_example_data.csv')

# %%
ces.head()
# Out:
#    pew_religimp  pew_churatd  sex  educ  nonwhite  age  faminc_new  pid3  \
# 0             2            6    2     2         1   56           6     1
# 1             2            4    2     5         1   53          13     1
# 2             1            2    1     2         1   69          10     2
# 3             2            3    1     6         1   76          97     1
# 4             4            5    2     6         1   83           4     1
#
#    ideo5  QueerPhobia  ...  InterGBiasParty  InterGBiasCand  InterGBiasSup  \
# 0      1     1.000000  ...              -99             -99            -96
# 1      2     3.000000  ...             -100            -100           -100
# 2      5     4.333333  ...               99              99             96
# 3      3     1.000000  ...              -86             -91            -89
# 4      2     1.000000  ...              -80             -88            -87
#
# ...

# %%
ces[['sex', 'age', 'pid3']].head(50)
# Out:
#     sex  age  pid3
# 0     2   56     1
# 1     2   53     1
# 2     1   69     2
# 3     1   76     1
# 4     2   83     1
# 5     1   87     3
# 6     1   83     3
# 7     1   69     3
# 8     1   84     3
# 9     2   63     1
# 10    1   54     2
# 11    2   46     1
# 12    2   49     3
# 13    2   35     3
# 14    2   54     2
# 15    1   77     3
# 16    2   61     3
# 17    2   66     1
# 18    1   67     1
# 19    2   44     2
# 20    1   30     3
# 21    2   57     1
# 22    2   56     3
# 23    2   72     2
# 24    2   47     2
# 25    2   52     1
# 26    1   32     2
# 27    2   65     2
# 28    2   86     1
# 29    1   60     3
# 30    2   57     2
# 31    2   73     1
# 32    2   29     1
# 33    2   58     1
# 34    2   77     2
# 35    2   78     3
# 36    2   40     1
# 37    2   48     3
# 38    2   33     2
# 39    1   73     1
# 40    1   35     1
# 41    1   36     1
# 42    1   47     3
# 43    2   40     1
# 44    1   45     1
# 45    2   38     2
# ...

# %%
ces.columns
# Out:
# Index(['pew_religimp', 'pew_churatd', 'sex', 'educ', 'nonwhite', 'age',
#        'faminc_new', 'pid3', 'ideo5', 'QueerPhobia', 'ImmiPhobia',
#        'InterGBiasParty', 'InterGBiasCand', 'InterGBiasSup', 'LibMediaUse',
#        'ConMediaUse', 'Real_Threat', 'Symb_Threat', 'Evaluation', 'teamweight',
#        'caseid'],
#       dtype='object')

# %%
ces['age'].hist()
plt.show()

# %%
fig1, ax1 = plt.subplots()
ax1.hist(ces['age'])
plt.show()

# %%
fig1, ax1 = plt.subplots(1, 2)
ax1[0].hist(ces['age'])
ax1[1].hist(ces['Symb_Threat'])
plt.show()

# %%
ces['pid3'].hist(bins = 3)
plt.show()

# %%
ces['Symb_Threat'].hist(bins = 4)
plt.show()

# %%
ces[ces['pid3'] == 1]['pid3']
# Out:
# 0      1
# 1      1
# 3      1
# 4      1
# 9      1
#       ..
# 648    1
# 649    1
# 654    1
# 655    1
# 656    1
# Name: pid3, Length: 251, dtype: int64

# %%
ones = ces[ces['pid3'] == 1]['Symb_Threat']
twos = ces[ces['pid3'] == 2]['Symb_Threat']
threes = ces[ces['pid3'] == 3]['Symb_Threat']

fig2, ax2 = plt.subplots()
ax2.boxplot(ones, positions = [1], widths = [.75])
ax2.boxplot(twos, positions = [2], widths = [.75])
ax2.boxplot(threes, positions = [3], widths = [.75])
plt.show()

# %%
ces.boxplot('Symb_Threat', by = 'pid3')
plt.show()

# %%
all_data = [np.random.normal(0, std, 100) for std in range(6, 10)]

# %%
fig3, ax3 = plt.subplots()
ax3.violinplot(ces['Symb_Threat'], showmeans = True)
plt.show()

# %%
fig4, ax4 = plt.subplots()
ax4.violinplot([ones, twos, threes], showmeans = True)
ax4.set_xticks([1, 2, 3], labels = ['ones', 'twos', 'threes'])
plt.show()

# %%
# Save for next class
figx, axx = plt.subplots()
axx.scatter(ces['age'], ces['Symb_Threat'], alpha = .3)
plt.show()
