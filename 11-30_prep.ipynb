# %% [markdown]
# ##### Remember
# - conda install statsmodels
# - pip install stargazer

# %%
import numpy as np
import pandas as pd
from statsmodels.formula import api as sm
from stargazer.stargazer import Stargazer
from IPython.core.display import HTML

# %%
ces = pd.read_csv('in-class_notebooks/cces_example_data.csv')
ces.head()
# Out:
#    pew_religimp  pew_churatd  sex  educ  nonwhite  age  faminc_new  pid3  \
# 0             2            6    2     2         1   56           6     1
# 1             2            4    2     5         1   53          13     1
# 2             1            2    1     2         1   69          10     2
# 3             2            3    1     6         1   76          97     1
# 4             4            5    2     6         1   83           4     1
#
#    ideo5  QueerPhobia  ...  InterGBiasParty  InterGBiasCand  InterGBiasSup  \
# 0      1     1.000000  ...              -99             -99            -96
# 1      2     3.000000  ...             -100            -100           -100
# 2      5     4.333333  ...               99              99             96
# 3      3     1.000000  ...              -86             -91            -89
# 4      2     1.000000  ...              -80             -88            -87
#
# ...

# %%
ces.columns
# Out:
# Index(['pew_religimp', 'pew_churatd', 'sex', 'educ', 'nonwhite', 'age',
#        'faminc_new', 'pid3', 'ideo5', 'QueerPhobia', 'ImmiPhobia',
#        'InterGBiasParty', 'InterGBiasCand', 'InterGBiasSup', 'LibMediaUse',
#        'ConMediaUse', 'Real_Threat', 'Symb_Threat', 'Evaluation', 'teamweight',
#        'caseid'],
#       dtype='object')

# %%
model_1 = sm.ols("Symb_Threat ~ age + faminc_new + ideo5", data = ces)

# %%
model_1.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            Symb_Threat   R-squared:                       0.037
# Model:                            OLS   Adj. R-squared:                  0.032
# Method:                 Least Squares   F-statistic:                     8.273
# Date:                Wed, 29 Nov 2023   Prob (F-statistic):           2.08e-05
# Time:                        11:07:06   Log-Likelihood:                -899.65
# No. Observations:                 659   AIC:                             1807.
# Df Residuals:                     655   BIC:                             1825.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.9573      0.142     27.820      0.000       3.678       4.237
# ...

# %%
results_1 = model_1.fit()
model_1_table = Stargazer([results_1])
HTML(model_1_table.render_html())
# Out:
# <table style="text-align:center"><tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td colspan="1"><em>Dependent variable: Symb_Threat</em></td></tr><tr><td style="text-align:left"></td><tr><td style="text-align:left"></td><td>(1)</td></tr>
# <tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr>
#
# <tr><td style="text-align:left">Intercept</td><td>3.957<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.142)</td></tr>
# <tr><td style="text-align:left">age</td><td>0.006<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.002)</td></tr>
# <tr><td style="text-align:left">faminc_new</td><td>0.002<sup>*</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.001)</td></tr>
# <tr><td style="text-align:left">ideo5</td><td>-0.121<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.029)</td></tr>
#
# ...

# %%
ces['pid3_labeled'] = ces['pid3'].replace([1,2,3], ['Dem', 'Rep', 'Ind'])

# %%
model_2 = sm.ols("LibMediaUse ~ C(pid3_labeled)", data = ces)

# %%
model_2.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            LibMediaUse   R-squared:                       0.172
# Model:                            OLS   Adj. R-squared:                  0.169
# Method:                 Least Squares   F-statistic:                     67.96
# Date:                Wed, 29 Nov 2023   Prob (F-statistic):           1.50e-27
# Time:                        11:07:06   Log-Likelihood:                -1080.4
# No. Observations:                 659   AIC:                             2167.
# Df Residuals:                     656   BIC:                             2180.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...
